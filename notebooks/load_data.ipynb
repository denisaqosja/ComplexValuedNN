# %%
import torch, os 
import numpy as np
import matplotlib.pyplot as plt

# %%
projects_path = os.path.dirname(os.path.dirname(os.getcwd()))
dataroot = os.path.join(projects_path, "Nekora/Datasets/Measured_Dataset/Data")

# %%
val_datapath = os.path.join(dataroot, "HR", "val", "rdmap.npy")
train_datapath = os.path.join(dataroot, "HR", "train", "rdmap.npy")
test_datapath = os.path.join(dataroot, "HR", "test", "rdmap.npy")

# %%
# load the files
train_data = np.load(train_datapath)
val_data = np.load(val_datapath)
test_data = np.load(test_datapath)

# %%
print(val_data.shape)
print(test_data.shape)
# Out:
# (19, 128, 256, 2)
# (148, 128, 256, 2)

# %%
plt.pcolor(np.log10(np.abs(val_data[0,:, :, 0])))
